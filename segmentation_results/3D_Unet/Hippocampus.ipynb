# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("/content/results-hauss-2D-L1 (1).csv").convert_dtypes()
sns.histplot(data=data["metric"], stat="probability", kde=True, color='darkblue')
# Out:
# <Axes: xlabel='metric', ylabel='Probability'>

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("/content/results-hauss-3D-L1 (5).csv").convert_dtypes()
sns.histplot(data=data["metric"], stat="probability", kde=True, color='darkblue', bins = 50)
# Out:
# <Axes: xlabel='metric', ylabel='Probability'>
